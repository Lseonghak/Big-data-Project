# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./new_train+distance_final.csv')
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  multiple_deliveries        e_Time_Orderd  \
# 0                 0           2                  1.0  1900-01-01 20:10:00
# 1                 1           3                  1.0  1900-01-01 19:25:00
# 2                 2           4                  1.0  1900-01-01 12:10:00
# 3                 3           5                  0.0  1900-01-01 22:20:00
# 4                 4           6                  0.0  1900-01-01 22:20:00
# ...             ...         ...                  ...                  ...
# 22076         22076       30500                  1.0  1900-01-01 22:15:00
# 22077         22077       30501                  1.0  1900-01-01 20:10:00
# 22078         22078       30503                  1.0  1900-01-01 12:55:00
# 22079         22079       30506                  0.0  1900-01-01 09:25:00
# 22080         22080       30508                  1.0  1900-01-01 20:15:00
#
#        e_Time_Order_picked  weekday  weekend  holiday  Time_taken (min)  \
# ...

# %%
zero = df[df['multiple_deliveries'] == 0].index
df.drop(zero, inplace=True)
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  multiple_deliveries        e_Time_Orderd  \
# 0                 0           2                  1.0  1900-01-01 20:10:00
# 1                 1           3                  1.0  1900-01-01 19:25:00
# 2                 2           4                  1.0  1900-01-01 12:10:00
# 6                 6          10                  1.0  1900-01-01 09:40:00
# 7                 7          11                  1.0  1900-01-01 17:45:00
# ...             ...         ...                  ...                  ...
# 22075         22075       30498                  1.0  1900-01-01 13:40:00
# 22076         22076       30500                  1.0  1900-01-01 22:15:00
# 22077         22077       30501                  1.0  1900-01-01 20:10:00
# 22078         22078       30503                  1.0  1900-01-01 12:55:00
# 22080         22080       30508                  1.0  1900-01-01 20:15:00
#
#        e_Time_Order_picked  weekday  weekend  holiday  Time_taken (min)  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'multiple_deliveries', 'e_Time_Orderd',
#        'e_Time_Order_picked', 'weekday', 'weekend', 'holiday',
#        'Time_taken (min)', 'distance', 'Weather conditions_Cloudy',
#        'Weather conditions_Fog', 'Weather conditions_Sandstorms',
#        'Weather conditions_Stormy', 'Weather conditions_Sunny',
#        'Weather conditions_Windy', 'Road_traffic_density_High',
#        'Road_traffic_density_Jam', 'Road_traffic_density_Low',
#        'Road_traffic_density_Medium', 'Vehicle_condition',
#        'Type_of_order_Buffet', 'Type_of_order_Drinks', 'Type_of_order_Meal',
#        'Type_of_order_Snack', 'Type_of_vehicle_electric_scooter',
#        'Type_of_vehicle_motorcycle', 'Type_of_vehicle_scooter', 'Festival',
#        'City_Metropolitian', 'City_Semi-Urban', 'City_Urban'],
#       dtype='object')

# %%
col = df['multiple_deliveries']*40 + df['distance'] + df['Festival']*40 + df['Road_traffic_density_Jam']*30 - df['Road_traffic_density_Low']*25

df['test'] = col

# %%
tmp = df[['multiple_deliveries','distance','Time_taken (min)','Festival','Road_traffic_density_Jam','Road_traffic_density_Low','test']]
tmp
# Out:
#        multiple_deliveries  distance  Time_taken (min)  Festival  \
# 0                      1.0      20.7                19         0
# 1                      1.0      25.4                31         0
# 2                      1.0      11.1                15         0
# 6                      1.0       4.8                15         0
# 7                      1.0      11.2                26         0
# ...                    ...       ...               ...       ...
# 22075                  1.0      10.6                19         0
# 22076                  1.0      15.0                18         0
# 22077                  1.0       8.4                42         0
# 22078                  1.0       8.5                24         0
# 22080                  1.0      17.2                16         0
#
#        Road_traffic_density_Jam  Road_traffic_density_Low  test
# 0                             1                         0  90.7
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(tmp.corr(), annot=True)
plt.title('heatmap')
plt.figure(figsize=(8,6))
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /Users/seonghak/Library/Python/3.10/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print(len(df['weekday']))
print(df['holiday'].sum())
# Out:
# 15035
# 307

# %%
x = df['holiday']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.5)
plt.xlabel("holiday")
plt.ylabel('time_taken')
plt.show()

# %%
x = df['distance']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.5)
plt.xlabel("distance")
plt.ylabel('time_taken')
plt.show()

# %%
x = df['Vehicle_condition']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.1)
plt.show()

# %%
x = df['multiple_deliveries']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.1)
plt.show()

# %%
x = df['Road_traffic_density_Low']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.1)
plt.show()

# %%
x = df['Road_traffic_density_Jam']
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.1)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %% [markdown]
# <b>multiple_deliveries가 높을수록 더 많은 시간이 걸리는 것을 알 수 있다.</b>

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
 
for i in range(len(['orange', 'blue'])):
    ax.scatter(np.array(df['distance']), np.array(df['multiple_deliveries']), np.array(df['Time_taken (min)']), s=50, alpha=0.5)
 
ax.set_xlabel('distance')
ax.set_ylabel('multiple_deliveries')
ax.set_zlabel('Time_taken')
 
# View Angle 조정하기
ax.view_init(20,40)
 
plt.show()

# %%
x = df['Festival']
y = df['Time_taken (min)']

plt.scatter(x,y)    
plt.show()

# %%
x = df['e_Time_Orderd'].sort_index()
y = df['Time_taken (min)']

plt.scatter(x,y, alpha=0.2)
plt.show()

# %%
x = df['Road_traffic_density_Jam']
y = df['Time_taken (min)']

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
 
for i in range(len(['orange', 'blue'])):
    ax.scatter(np.array(df['Road_traffic_density_Jam']), np.array(df['multiple_deliveries']), np.array(df['Time_taken (min)']), s=50, alpha=0.2)
 
ax.set_xlabel('Road_traffic_density_Jam')
ax.set_ylabel('multiple_deliveries')
ax.set_zlabel('Time_taken')
 
# View Angle 조정하기
ax.view_init(20,40)
 
plt.show()

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import boxplot
tmp
tmp.drop(['test'], axis=1, inplace=True)
# Out:
# /var/folders/rp/pmxnnzn55wx5xyvnnpmx4d3m0000gn/T/ipykernel_72355/3527742934.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp.drop(['test'], axis=1, inplace=True)

# %%
tmp
# Out:
#        multiple_deliveries  distance  Time_taken (min)  Festival  \
# 0                      1.0      20.7                19         0
# 1                      1.0      25.4                31         0
# 2                      1.0      11.1                15         0
# 6                      1.0       4.8                15         0
# 7                      1.0      11.2                26         0
# ...                    ...       ...               ...       ...
# 22075                  1.0      10.6                19         0
# 22076                  1.0      15.0                18         0
# 22077                  1.0       8.4                42         0
# 22078                  1.0       8.5                24         0
# 22080                  1.0      17.2                16         0
#
#        Road_traffic_density_Jam  Road_traffic_density_Low
# 0                             1                         0
# 1                             1                         0
# ...

# %%
tmp[tmp['distance'] > 40]
# Out:
#        multiple_deliveries  distance  Time_taken (min)  Festival  \
# 71                     1.0      48.0                37         0
# 85                     1.0      43.0                30         0
# 295                    1.0      45.2                37         0
# 302                    1.0      48.5                21         0
# 343                    1.0      41.5                41         0
# ...                    ...       ...               ...       ...
# 21624                  1.0      41.4                20         0
# 21754                  1.0      50.2                24         0
# 21769                  1.0      42.3                24         0
# 21794                  1.0      43.9                26         0
# 22053                  2.0      46.5                48         0
#
#        Road_traffic_density_Jam  Road_traffic_density_Low
# 71                            0                         0
# 85                            0                         0
# ...

# %%
plt.boxplot(tmp)
plt.show()

# %%
df = pd.read_csv('new_train_distance_final3.csv')
df
# Out:
#        Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0                 0           0             0               2
# 1                 1           1             1               3
# 2                 2           2             2               4
# 3                 3           6             6              10
# 4                 4           7             7              11
# ...             ...         ...           ...             ...
# 15030         15030       22075         22075           30498
# 15031         15031       22076         22076           30500
# 15032         15032       22077         22077           30501
# 15033         15033       22078         22078           30503
# 15034         15034       22080         22080           30508
#
#        multiple_deliveries        e_Time_Orderd  e_Time_Order_picked  weekday  \
# 0                      1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        2
# ...

# %%
df.drop(['Unnamed: 0.2','Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'], inplace=True, axis=1)

# %%
df.drop(['no식사'], inplace=True, axis=1)

# %%
def outliers_iqr(data):
    q1, q3 = np.percentile(data, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr *1.5)
    upper_bound = q3 + (iqr *1.5)
    
    return np.where((data > upper_bound)|(data < lower_bound))

# %%
import numpy as np
distance = outliers_iqr(df['distance'])[0]
print(distance)
df.drop(distance, inplace=True, axis=0)
# Out:
# [   45    54   197   202   234   272   304   309   343   391   473   609
#    620   726   851   893   910   943   950  1196  1218  1303  1338  1440
#   1492  1550  1579  1603  1938  2010  2176  2180  2183  2298  2318  2578
#   2586  2608  2692  2815  2926  2940  2946  2947  2994  3030  3138  3192
#   3301  3305  3410  3494  3638  3682  3702  3737  3806  3941  3972  4008
#   4099  4245  4314  4522  4532  4750  4785  4792  4820  4904  5030  5049
#   5206  5248  5361  5412  5537  5641  5649  5654  5833  5905  6009  6031
#   6051  6115  6220  6251  6447  6481  6515  6556  6669  6816  6859  6866
#   6876  6970  6999  7226  7402  7482  7733  7742  7775  7783  7821  7865
#   7956  8014  8053  8102  8117  8353  8381  8415  8494  8514  8520  8553
#   8608  8644  8659  8692  8770  8809  8929  9049  9121  9154  9222  9260
#   9399  9436  9474  9486  9553  9725  9752  9754  9987  9989 10066 10080
#  10081 10179 10248 10362 10371 10403 10454 10462 10494 10500 10725 10891
# ...

# %%
df
# Out:
#        multiple_deliveries        e_Time_Orderd  e_Time_Order_picked  weekday  \
# 0                      1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        2
# 1                      1.0  1900-01-01 19:25:00  1900-01-01 19:35:00        4
# 2                      1.0  1900-01-01 12:10:00  1900-01-01 12:20:00        5
# 3                      1.0  1900-01-01 09:40:00  1900-01-01 09:55:00        6
# 4                      1.0  1900-01-01 17:45:00  1900-01-01 18:00:00        3
# ...                    ...                  ...                  ...      ...
# 15030                  1.0  1900-01-01 13:40:00  1900-01-01 13:50:00        2
# 15031                  1.0  1900-01-01 22:15:00  1900-01-01 22:30:00        5
# 15032                  1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        1
# 15033                  1.0  1900-01-01 12:55:00  1900-01-01 13:10:00        0
# 15034                  1.0  1900-01-01 20:15:00  1900-01-01 20:25:00        2
#
# ...

# %%
time = outliers_iqr(df['Time_taken (min)'])[0]
print(np.where(time==726))
print(np.where(time==4904)) 
print(np.where(time==12606)) 
time = np.delete(time, (2,34,82))
df.drop(time, inplace=True,axis=0)
# df
# Out:
# (array([2]),)
# (array([34]),)
# (array([82]),)

# %%
df
# Out:
#        multiple_deliveries        e_Time_Orderd  e_Time_Order_picked  weekday  \
# 0                      1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        2
# 1                      1.0  1900-01-01 19:25:00  1900-01-01 19:35:00        4
# 2                      1.0  1900-01-01 12:10:00  1900-01-01 12:20:00        5
# 3                      1.0  1900-01-01 09:40:00  1900-01-01 09:55:00        6
# 4                      1.0  1900-01-01 17:45:00  1900-01-01 18:00:00        3
# ...                    ...                  ...                  ...      ...
# 15030                  1.0  1900-01-01 13:40:00  1900-01-01 13:50:00        2
# 15031                  1.0  1900-01-01 22:15:00  1900-01-01 22:30:00        5
# 15032                  1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        1
# 15033                  1.0  1900-01-01 12:55:00  1900-01-01 13:10:00        0
# 15034                  1.0  1900-01-01 20:15:00  1900-01-01 20:25:00        2
#
# ...

# %%
plt.boxplot(df['distance'])
plt.show()

# %%
plt.boxplot(df['Time_taken (min)'])
plt.show()

# %%
df
# Out:
#        multiple_deliveries        e_Time_Orderd  e_Time_Order_picked  weekday  \
# 0                      1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        2
# 1                      1.0  1900-01-01 19:25:00  1900-01-01 19:35:00        4
# 2                      1.0  1900-01-01 12:10:00  1900-01-01 12:20:00        5
# 3                      1.0  1900-01-01 09:40:00  1900-01-01 09:55:00        6
# 4                      1.0  1900-01-01 17:45:00  1900-01-01 18:00:00        3
# ...                    ...                  ...                  ...      ...
# 15030                  1.0  1900-01-01 13:40:00  1900-01-01 13:50:00        2
# 15031                  1.0  1900-01-01 22:15:00  1900-01-01 22:30:00        5
# 15032                  1.0  1900-01-01 20:10:00  1900-01-01 20:25:00        1
# 15033                  1.0  1900-01-01 12:55:00  1900-01-01 13:10:00        0
# 15034                  1.0  1900-01-01 20:15:00  1900-01-01 20:25:00        2
#
# ...

# %%
df.to_csv('new_train_distance_final4.csv')
